# %% [markdown]
# # Experiments and results

# %% [markdown]
# Here the results of the experiments are plotted.

# %% [markdown]
# ### Plotting functions

# %%
import sys
sys.path.append("src/")

import configuration
from constants import Constants as CT
import os
import tensorflow as tf
import glob
import pandas as pd
from matplotlib import pyplot as plt
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    """
    Curve smoothing https://en.wikipedia.org/wiki/Savitzky%E2%80%93Golay_filter
    """
    import numpy as np
    from math import factorial
    y = np.array(y)
    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

def get_single_series(path_to_events_file, scalar_key):
    model_name = path_to_events_file.split(os.path.sep)[-2]
    print("\tGetting %s" % (scalar_key))#, model_name))
    steps = []
    values = []
    for e in tf.train.summary_iterator(path_to_events_file):   
        for v in e.summary.value:
            if scalar_key in v.tag:
                values.append(v.simple_value)
                steps.append(e.step)
    series = pd.Series(index = steps, data = values)
    return series

def get_all_series_averaged(folder_keys, scalar_key, experiment_folder,
                                                                steps_mode, smooth = True):
    assert os.path.isdir(experiment_folder), "Not a dir: %s" % experiment_folder
    folder_keys = [folder_keys] if type(folder_keys) is not list else folder_keys
    print("Searching for folder_key='%s'" % str(folder_keys))
    series_list = []
    run_paths = []
    for f in os.listdir(experiment_folder):
        if all([folder_key in f for folder_key in folder_keys]):
            run_paths.append(os.path.join(experiment_folder, f))
                              
    assert len(run_paths) > 0, "No matches"
    training_times = []
    for run_path in run_paths:
        try:
            path_to_events_file = glob.glob(os.path.join(run_path,'events.out*'))[0]
        except IndexError:
            print("\tHasn't even started" % run_path)
            series = pd.Series()
        else:
            series = get_single_series(path_to_events_file, scalar_key)
        try:
            with open(os.path.join(run_path,'total_training_seconds.txt')) as fp:
                content = fp.read()
            training_time = float(content) / 3600
            training_times.append(training_time)
        except:
            print("\tNot finished (length = %d) " % len(series))
        series_list.append(series)
#         print(len(series))
    
    df = pd.DataFrame(series_list)
    means = df.mean(axis = 0)
    if smooth:
        means = savitzky_golay(means, 51, 3)
    stds = df.std(axis = 0)
    steps = df.columns.to_series()
    
    if steps_mode == 'millions':
        steps /= 1e6
    elif steps_mode == 'thousands':
        steps /= 1e3
    try:
        avg_training_time = sum(training_times) / len(training_times)
    except:
        avg_training_time = -1
    data = {'means'      : means,
            'stds'       : stds,
            'steps'      : steps,
            'time'       : avg_training_time,
            'scalar_key' : scalar_key}
                
    return data


def get_datas(folder_keys, scalar_key, experiment_folder, steps_mode):
    datas = []
    for folder_key in folder_keys:
        data = get_all_series_averaged(folder_keys = folder_key,
                                       scalar_key = scalar_key,
                                       experiment_folder = experiment_folder,
                                       steps_mode = steps_mode)
        datas.append(data)    
    return datas

def custom_subplot(data, label, time):
    err, means, steps, t = data['stds'], data['means'], data['steps'], data['time']
    if len(steps) == 0:
        print("(empty)")
        return
    if time:
        final_label = "(%.1fh) %s" % (t, label)
    else:
        final_label = label
    plt.plot(steps, means, label = final_label)
    plt.fill_between(steps,
                     means - err,
                     means + err,
                     alpha = alpha, linewidth = linewidth) 
    
def make_plot(datas, labels, time = True, legend_loc = 'lower right', title = None):
    plt.figure(figsize = figsize)
    for data, label in zip(datas, labels):
        custom_subplot(data, label, time)
    title = data['scalar_key'] if not title else title
    plt.ylabel(title, fontsize = fontsize)
    plt.xlabel('%s of steps' % steps_mode.capitalize(), fontsize = fontsize)
    plt.legend(fontsize = fontsize,
               loc = legend_loc)
    plt.show()  

# Global variables:
gl = configuration.GlobalSettings()
alpha = .3
linewidth = 0
fontsize = 15
figsize = (12, 7)
steps_mode = 'millions'
scalar_key = 'avg_ep_reward'

# %% [markdown]
# ### Intrinsic reward time penalty

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/13d23h47m00s_intrinsic_exp'
steps_mode = 'millions'   
labels = ['With time penalty', 'Without time penalty']
cits = [ 'Citp0.01',  'Citp0_']
datass = []
goal_groups = [1, 2]
for gg in goal_groups:
    goals = CT.goal_groups['SF-v0'][gg]
    for goal in goals:
        datas = []
        scalar_key = '%s_avg_steps' % goal
        for cit in cits:
            folder_keys = ["gg%d" % gg, cit]
            data = get_all_series_averaged(folder_keys = folder_keys,
                                           scalar_key = scalar_key,
                                           experiment_folder = experiment_folder,
                                           steps_mode = steps_mode)
            datas.append(data)
        datass.append(datas)
# Out:
# Searching for folder_key='['gg1', 'Citp0.01']'
# 	Getting G_aim_at_fortress_avg_steps
# 	Getting G_aim_at_fortress_avg_steps
# 	Getting G_aim_at_fortress_avg_steps
# Searching for folder_key='['gg1', 'Citp0_']'
# 	Getting G_aim_at_fortress_avg_steps
# 	Getting G_aim_at_fortress_avg_steps
# 	Getting G_aim_at_fortress_avg_steps
# Searching for folder_key='['gg1', 'Citp0.01']'
# 	Getting G_aim_at_mine_avg_steps
# 	Getting G_aim_at_mine_avg_steps
# 	Getting G_aim_at_mine_avg_steps
# Searching for folder_key='['gg1', 'Citp0_']'
# 	Getting G_aim_at_mine_avg_steps
# 	Getting G_aim_at_mine_avg_steps
# 	Getting G_aim_at_mine_avg_steps
# Searching for folder_key='['gg1', 'Citp0.01']'
# 	Getting G_double_shoot_avg_steps
# 	Getting G_double_shoot_avg_steps
# 	Getting G_double_shoot_avg_steps
# Searching for folder_key='['gg1', 'Citp0_']'
# 	Getting G_double_shoot_avg_steps
# 	Getting G_double_shoot_avg_steps
# 	Getting G_double_shoot_avg_steps
# Searching for folder_key='['gg1', 'Citp0.01']'
# 	Getting G_single_shoot_avg_steps
# 	Getting G_single_shoot_avg_steps
# 	Getting G_single_shoot_avg_steps
# Searching for folder_key='['gg1', 'Citp0_']'
# 	Getting G_single_shoot_avg_steps
# 	Getting G_single_shoot_avg_steps
# 	Getting G_single_shoot_avg_steps
# Searching for folder_key='['gg2', 'Citp0.01']'
# 	Getting G_hit_mine_avg_steps
# 	Getting G_hit_mine_avg_steps
# 	Getting G_hit_mine_avg_steps
# Searching for folder_key='['gg2', 'Citp0_']'
# 	Getting G_hit_mine_avg_steps
# 	Getting G_hit_mine_avg_steps
# 	Getting G_hit_mine_avg_steps
# Searching for folder_key='['gg2', 'Citp0.01']'
# 	Getting G_hit_fortress_once_avg_steps
# 	Getting G_hit_fortress_once_avg_steps
# 	Getting G_hit_fortress_once_avg_steps
# Searching for folder_key='['gg2', 'Citp0_']'
# 	Getting G_hit_fortress_once_avg_steps
# 	Getting G_hit_fortress_once_avg_steps
# 	Getting G_hit_fortress_once_avg_steps
# Searching for folder_key='['gg2', 'Citp0.01']'
# 	Getting G_hit_fortress_twice_avg_steps
# 	Getting G_hit_fortress_twice_avg_steps
# 	Getting G_hit_fortress_twice_avg_steps
# Searching for folder_key='['gg2', 'Citp0_']'
# 	Getting G_hit_fortress_twice_avg_steps
# 	Getting G_hit_fortress_twice_avg_steps
# 	Getting G_hit_fortress_twice_avg_steps

# %%
plt.figure(figsize = (14, 7))
columns = 4
rows = 2
total_figures = columns * rows
for i in range(total_figures - 1):
    plot_pos = i + 1
    plt.subplot(rows, columns, plot_pos)
    datas = datass[i]
    for data, label in zip(datas, labels):
        custom_subplot(data, label, time = False)
    title = data['scalar_key'][2:-10].replace('_', ' ').capitalize()
    plt.title(title, fontsize = fontsize)
    if i == total_figures - 2:
        plt.legend(fontsize = fontsize,
                   bbox_to_anchor=(2.32, .8))
        
    
plt.show()

# %%
'G_aim_at_fortress_avg_steps'[2:-10].replace('_', ' ').capitalize()
# Out:
# 'Aim at fortress'

# %%
for datas in datass:
    make_plot(datas, labels, time = False)

# %% [markdown]
# ### h-DQN Extensions

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/04d09h25m45s_extensions_exp'
labels = ['Vanilla', 'Double Q', 'Dueling', 'Prioritized Replay', 'Rainbow']
folder_keys = [ 'dq0_d0_p0',  'dq1_d0_p0', 'dq0_d1_p0', 'dq0_d0_p1', 'dq1_d1_p1']
scalar_key = 'win_rate'
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)
# Out:
# Searching for folder_key='dq0_d0_p0'
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs4
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs3
# 	Not finished
# Searching for folder_key='dq1_d0_p0'
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d0_p0_ar6_rs4
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d0_p0_ar6_rs0
# 	Not finished
# Searching for folder_key='dq0_d1_p0'
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d1_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d1_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d1_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d1_p0_ar6_rs4
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d1_p0_ar6_rs2
# 	Not finished
# Searching for folder_key='dq0_d0_p1'
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p1_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p1_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p1_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p1_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m45s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p1_ar6_rs4
# 	Not finished
# Searching for folder_key='dq1_d1_p1'
# 	Getting win_rate from d07d21h21m10s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d1_p1_ar6_rs3
# 	Not finished
# 	Getting win_rate from d07d22h40m35s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d1_p1_ar6_rs1
# 	Not finished
# 	Getting win_rate from d07d22h59m51s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d1_p1_ar6_rs2
# 	Not finished
# 	Getting win_rate from d08d05h26m44s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d1_p1_ar6_rs0
# 	Not finished
# 	Getting win_rate from d08d07h20m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq1_d1_p1_ar6_rs4
# 	Not finished

# %%
make_plot(datas, labels, legend_loc = 'upper left')

# %% [markdown]
# ### DQN Extensions

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/23d20h16m07s_extensions_exp'
labels = ['Vanilla', 'Double Q', 'Dueling', 'Prioritized Replay', 'Rainbow']
folder_keys = [ 'dq0_d0_p0',  'dq1_d0_p0', 'dq0_d1_p0', 'dq0_d0_p1', 'dq1_d1_p1']
scalar_key = 'win_rate'
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)

# %%
make_plot(datas, labels)

# %% [markdown]
# ### Action repeat

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/04d09h25m33s_action_repeat_exp'
actions_repeats = list(range(1, 8))
labels = ["ar=%d" % ar for ar in actions_repeats]
folder_keys = ["ar%d_" % ar for ar in actions_repeats]
scalar_key = 'win_rate'
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)
# Out:
# Searching for folder_key='ar1_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs3
# 	Not finished
# Searching for folder_key='ar2_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar2_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar2_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar2_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar2_rs2
# 	Not finished
# Searching for folder_key='ar3_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs1
# 	Not finished
# Searching for folder_key='ar4_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar4_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar4_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar4_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar4_rs0
# 	Not finished
# Searching for folder_key='ar5_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs1
# 	Not finished
# Searching for folder_key='ar6_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs1
# 	Not finished
# Searching for folder_key='ar7_'
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m33s_gg4_enSF-v0_e1_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs2
# 	Not finished

# %%
make_plot(datas, labels)

# %% [markdown]
# ### Architectures

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/21d18h32m35s_architectures_exp'
architectures = [[16],
                [64, 64],
                [64, 64, 64, 64],
                [512],
                [512, 512],
                [512, 512, 512, 512]]
labels = ['-'.join([str(n) for n in a]) for a in architectures]
folder_keys = ['a' + l + '_' for l in labels]
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)

# %% [markdown]
# ### Architectures h-DQN

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/04d09h25m40s_architectures_exp'
architectures = [[16],
                [64],
                [64, 64],
                [64, 64, 64, 64],
                [512],
                [512, 512],
                [512, 512, 512, 512]]
scalar_key = 'win_rate'
labels = ['-'.join([str(n) for n in a]) for a in architectures]
folder_keys = ['a' + l + '_' for l in labels]
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)
# Out:
# Searching for folder_key='a16_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a16_dq0_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a16_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a16_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a16_dq0_d0_p0_ar6_rs0
# 	Not finished
# Searching for folder_key='a64_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64_dq0_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64_dq0_d0_p0_ar6_rs0
# 	Not finished
# Searching for folder_key='a64-64_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64_dq0_d0_p0_ar6_rs1
# 	Not finished
# Searching for folder_key='a64-64-64-64_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64-64-64_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64-64-64_dq0_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64-64-64_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a64-64-64-64_dq0_d0_p0_ar6_rs2
# 	Not finished
# Searching for folder_key='a512_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512_dq0_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512_dq0_d0_p0_ar6_rs3
# 	Not finished
# Searching for folder_key='a512-512_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs2
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar6_rs1
# 	Not finished
# Searching for folder_key='a512-512-512-512_'
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512-512-512_dq0_d0_p0_ar6_rs0
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512-512-512_dq0_d0_p0_ar6_rs3
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512-512-512_dq0_d0_p0_ar6_rs1
# 	Not finished
# 	Getting win_rate from d04d09h25m40s_gg4_enSF-v0_e0_ma1_athdqn_a512-512-512-512_dq0_d0_p0_ar6_rs2
# 	Not finished

# %%
make_plot(datas, labels, legend_loc = 'lower left')

# %% [markdown]
# ### Goals

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/04d09h26m01s_goals_exp'
steps_mode = 'millions'
scalar_key = 'c_avg_goal_success'
goal_groups = [2,3,4,5]
labels = ['gg%d' % gg for gg in goal_groups]
folder_keys = labels#['a' + l + '_' for l in labels]
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)

# %%
make_plot(datas, labels)

# %% [markdown]
# ## Goal level of hierarchy versus action repeat

# %%
experiment_folder = '/vol/tensusers/vgarciacazorla/logs/10d17h18m46s_goals_exp'
steps_mode = 'millions'
scalar_key = 'win_rate'
goal_groups = [2,3]
labels = ['gg_'] + ['gg%d' % gg for gg in goal_groups]
folder_keys = labels#['a' + l + '_' for l in labels]
datas = get_datas(folder_keys, scalar_key, experiment_folder, steps_mode)
# Out:
# Searching for folder_key='gg_'
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar1_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar5_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar7_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar1_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar3_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar3_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar3_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar5_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar5_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar1_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar7_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg_enSF-v0_e0_ma1_atdqn_a512-512_dq0_d0_p0_ar7_rs0
# 	Not finished
# Searching for folder_key='gg2'
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg2_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs0
# 	Not finished
# Searching for folder_key='gg3'
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar7_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs0
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar5_rs1
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar1_rs2
# 	Not finished
# 	Getting win_rate from d10d17h18m46s_gg3_enSF-v0_e0_ma1_athdqn_a512-512_dq0_d0_p0_ar3_rs2
# 	Not finished

# %%
make_plot(datas, labels)
